# %%
import numpy as np
import pandas as pd

# %%
X = 2 * np.random.rand(100,1)

# %%
y = 4 + 3 * X + np.random.rand(100,1)

# %%
X_b = np.c_[np.ones((100,1)), X]
X_b
# Out:
# array([[1.        , 1.37414507],
#        [1.        , 0.94727505],
#        [1.        , 0.14235863],
#        [1.        , 0.87150597],
#        [1.        , 1.28397585],
#        [1.        , 0.76511507],
#        [1.        , 1.03651367],
#        [1.        , 1.86252403],
#        [1.        , 0.81655364],
#        [1.        , 0.71469718],
#        [1.        , 1.32184986],
#        [1.        , 1.87727342],
#        [1.        , 0.1600634 ],
#        [1.        , 1.58768274],
#        [1.        , 1.04479549],
#        [1.        , 0.31267672],
#        [1.        , 1.98973945],
#        [1.        , 1.608253  ],
#        [1.        , 0.7842135 ],
#        [1.        , 0.99551822],
#        [1.        , 1.94078774],
#        [1.        , 1.5351448 ],
#        [1.        , 0.7622306 ],
#        [1.        , 1.5461663 ],
#        [1.        , 0.02151628],
#        [1.        , 1.24404144],
#        [1.        , 0.74341387],
#        [1.        , 1.25710298],
# ...
